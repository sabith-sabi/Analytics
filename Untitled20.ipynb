# %%
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:/Users/DELL/Downloads/Book_1.xlsx")

# %%
df
# Out:
#               Name            Team  Number Position  Age     Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25 2023-02-06     180
# 1      Jae Crowder  Boston Celtics      99       SF   25 2023-06-06     235
# 2     John Holland  Boston Celtics      30       SG   27 2023-05-06     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22 2023-05-06     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29 2023-10-06     231
# ..             ...             ...     ...      ...  ...        ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26 2023-03-06     203
# 454      Raul Neto       Utah Jazz      25       PG   24 2023-01-06     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26 2023-03-07     256
# 456    Jeff Withey       Utah Jazz      24        C   26 2000-07-01     231
# 457       Priyanka       Utah Jazz      34        C   25 2023-03-07     231
#
#                College     Salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    datetime64[ns]
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 32.3+ KB

# %%
team_counts = df['Team'].value_counts()

# Calculate the percentage splitting with respect to the total number of employees
percentage_split = (team_counts / len(df)) * 100

# Print the results
print("Number of employees in each team:")
print(team_counts)
print("\nPercentage splitting with respect to the total number of employees:")
print(percentage_split)
# Out:
# Number of employees in each team:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64
#
# ...

# %%
team_counts.plot(kind='bar', figsize=(8, 6))
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Team')
plt.show()

# %%
grouped_data = df.groupby('Position')

# Iterate over each group and display the employees
for position, employees in grouped_data:
    print(f"\nEmployees in {position}:")
    print(employees)
# Out:
# Employees in C:
#                 Name                    Team  Number Position  Age     Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25 2000-07-01
# 10   Jared Sullinger          Boston Celtics       7        C   24 2023-09-06
# 14      Tyler Zeller          Boston Celtics      44        C   26 2000-07-01
# 23       Brook Lopez           Brooklyn Nets      11        C   28 2000-07-01
# 27        Henry Sims           Brooklyn Nets      14        C   26 2023-10-06
# ..               ...                     ...     ...      ...  ...        ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26 2023-11-06
# 447      Rudy Gobert               Utah Jazz      27        C   23 2023-01-07
# 455     Tibor Pleiss               Utah Jazz      21        C   26 2023-03-07
# 456      Jeff Withey               Utah Jazz      24        C   26 2000-07-01
# 457         Priyanka               Utah Jazz      34        C   25 2023-03-07
#
# ...

# %%
positions = df['Position'].unique()
employee_data = {}

for position in positions:
    employee_data[position] = df[df['Position'] == position]

# Create a scatter plot for each position
fig, ax = plt.subplots()

for position, data in employee_data.items():
    ax.scatter(data['Salary'], data['Age'], label=position)

ax.set_xlabel('Salary')
ax.set_ylabel('Age')
ax.set_title('Employee Distribution by Position')
ax.legend()
plt.show()

# %%
# Create a histogram of employee ages
plt.hist(df['Age'], bins=10, edgecolor='black')

# Customize the plot
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.title('Employee Age Distribution')

# Show the plot
plt.show()

# %%
grouped_data = df.groupby(['Team', 'Position'])['Salary'].sum()

# Find the team and position with the highest and lowest spending
highest_spending = grouped_data.idxmax()
lowest_spending = grouped_data.idxmin()

# Display the results
print("Highest Spending:")
print("Team:", highest_spending[0])
print("Position:", highest_spending[1])
print("Total Salary:", grouped_data[highest_spending])
print()

print("Lowest Spending:")
print("Team:", lowest_spending[0])
print("Position:", lowest_spending[1])
print("Total Salary:", grouped_data[lowest_spending])
# Out:
# Highest Spending:
# Team: Los Angeles Lakers
# Position: SF
# Total Salary: 31866445.0
#
# Lowest Spending:
# Team: Orlando Magic
# Position: SF
# Total Salary: 845059.0

# %%
correlation = df['Age'].corr(df['Salary'])

# Create a scatter plot
plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs Salary')

# Display correlation coefficient on the plot
plt.text(0.95, 0.05, f'Correlation: {correlation:.2f}', transform=plt.gca().transAxes, ha='right')

# Show the scatter plot
plt.show()

# Create a heat map of the correlation matrix
correlation_matrix = df[['Age', 'Salary']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Set the title of the heat map
plt.title('Correlation Heat Map: Age vs Salary')

# Show the heat map
plt.show()

# %%
import random
v=[]

for i in range(0,458):
    c=random.randint(100, 190)
    v.append(c)
v
# Out:
# [171,
#  187,
#  172,
#  182,
#  177,
#  109,
#  177,
#  103,
#  168,
#  175,
#  158,
#  164,
#  138,
#  168,
#  114,
#  101,
#  151,
#  131,
#  187,
#  119,
#  175,
#  186,
#  130,
#  160,
#  188,
#  180,
#  156,
#  181,
#  111,
#  148,
#  177,
#  114,
#  178,
#  124,
#  132,
#  165,
#  180,
#  164,
#  103,
#  136,
#  116,
#  174,
#  150,
#  128,
#  169,
#  174,
#  133,
#  154,
#  175,
#  150,
#  159,
#  150,
#  150,
#  190,
#  107,
#  156,
#  135,
#  131,
#  109,
#  140,
#  135,
#  180,
#  109,
#  143,
#  176,
#  102,
#  123,
#  143,
#  114,
#  189,
#  146,
#  181,
#  181,
#  170,
#  161,
#  105,
#  134,
#  119,
#  165,
#  125,
#  152,
#  134,
#  170,
#  118,
#  120,
#  160,
#  163,
#  124,
#  143,
#  159,
#  143,
#  170,
#  109,
#  182,
#  128,
#  178,
#  184,
#  162,
#  108,
#  175,
#  183,
#  184,
#  166,
#  171,
#  161,
#  129,
#  179,
#  158,
#  171,
#  166,
#  115,
#  160,
#  119,
#  171,
#  100,
#  124,
#  110,
#  154,
#  174,
#  130,
#  132,
#  139,
#  150,
#  154,
#  177,
# ...

# %%
d1=pd.DataFrame(v)
d1
# Out:
#        0
# 0    171
# 1    187
# 2    172
# 3    182
# 4    177
# ..   ...
# 453  153
# 454  124
# 455  189
# 456  135
# 457  158
#
# [458 rows x 1 columns]

# %%
df = pd.read_excel("C:/Users/DELL/Downloads/Book_1.xlsx")

# %%
df
# Out:
#               Name            Team  Number Position  Age     Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25 2023-02-06     180
# 1      Jae Crowder  Boston Celtics      99       SF   25 2023-06-06     235
# 2     John Holland  Boston Celtics      30       SG   27 2023-05-06     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22 2023-05-06     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29 2023-10-06     231
# ..             ...             ...     ...      ...  ...        ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26 2023-03-06     203
# 454      Raul Neto       Utah Jazz      25       PG   24 2023-01-06     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26 2023-03-07     256
# 456    Jeff Withey       Utah Jazz      24        C   26 2000-07-01     231
# 457       Priyanka       Utah Jazz      34        C   25 2023-03-07     231
#
#                College     Salary
# ...

# %%
df['Height']=v

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     187     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     182     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     153     203
# 454      Raul Neto       Utah Jazz      25       PG   24     124     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     189     256
# 456    Jeff Withey       Utah Jazz      24        C   26     135     231
# 457       Priyanka       Utah Jazz      34        C   25     158     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...
